# %%
# -*- coding: utf-8 -*-
import sys
import matplotlib.pyplot as plt
import pandas as pd

dataframe = pd.read_csv('./dados1.csv', delimiter=' ')
print(dataframe)
# Out:
#     NúmeroPáginas     Tempo
# 0              10  0.164000
# 1              25  0.128400
# 2              50  0.175000
# 3              75  0.188267
# 4             100  0.154600
# 5             250  0.173520
# 6             500  0.223060
# 7             750  0.207653
# 8            1000  0.114680
# 9            2500  0.053348
# 10           5000  0.039532
# 11           7500  0.038493
# 12          10000  0.038279
# 13          25000  0.037218
# 14          50000  0.037152
# 15         100000  0.037369
# 16         250000  0.038613
# 17         500000  0.038549

# %%
dataframe.plot()
plt.show()

# %%
dataframe2 = pd.read_csv('./dados2.csv', delimiter=' ')
print(dataframe2)
dataframe2.plot()
plt.show()
# Out:
#     NúmeroPáginas     Tempo
# 0              10  0.037000
# 1              25  0.030800
# 2              50  0.081400
# 3              75  0.039200
# 4             100  0.037800
# 5             250  0.035920
# 6             500  0.040980
# 7             750  0.040680
# 8            1000  0.038140
# 9            2500  0.039164
# 10           5000  0.037242
# 11           7500  0.041177
# 12          10000  0.036503
# 13          25000  0.037279
# 14          50000  0.037242
# 15         100000  0.037882
# 16         250000  0.039762
# 17         500000  0.039348
